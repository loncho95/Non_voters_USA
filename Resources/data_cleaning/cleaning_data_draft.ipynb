# %%
import pandas as pd

# %%
non_voters_or_df = pd.read_csv('../nonvoters_data.csv')
non_voters_or_df
# Out:
#       RespId  weight  Q1  Q2_1  Q2_2  Q2_3  Q2_4  Q2_5  Q2_6  Q2_7  ...  \
# 0     470001  0.7516   1     1     1     2     4     1     4     2  ...
# 1     470002  1.0267   1     1     2     2     3     1     1     2  ...
# 2     470003  1.0844   1     1     1     2     2     1     1     2  ...
# 3     470007  0.6817   1     1     1     1     3     1     1     1  ...
# 4     480008  0.9910   1     1     1    -1     1     1     1     1  ...
# ...      ...     ...  ..   ...   ...   ...   ...   ...   ...   ...  ...
# 5831  477662  1.1916   1     1     3     1     3     1     2     2  ...
# 5832  477663  1.4623   1     1     1     1     2     1     2     1  ...
# 5833  488322  0.9252   1     1     2     1     3     1     1     2  ...
# 5834  488325  2.6311   1     2     2     2     2     2     2     2  ...
# 5835  477666  1.6218   1     1     3     2     3     1     1     2  ...
#
#       ppage  educ  race  gender  income_cat  voter_category  voter_category.1  \
# ...

# %%
# Creation of df with relevant questions
new_non_voters_df = non_voters_or_df.loc[:, ['RespId', 'Q3_1', 'Q3_2', 'Q3_3', 'Q3_4', 'Q3_5', 'Q3_6', 'Q4_1', 'Q4_2', 'Q4_3', 'Q4_4', 'Q4_5', 'Q4_6', 'Q5', 'Q30', 'ppage', 'educ', 'race', 'gender', 'income_cat', 'voter_category']]
new_non_voters_df
# Out:
#       RespId  Q3_1  Q3_2  Q3_3  Q3_4  Q3_5  Q3_6  Q4_1  Q4_2  Q4_3  ...  Q4_5  \
# 0     470001     1     1     4     4     3     2     2     1     2  ...     2
# 1     470002     3     3     4     3     3     2     2     2     2  ...     3
# 2     470003     2     2     3     3     2     2     2     2     3  ...     2
# 3     470007     1     1     4     4     2     1     1     2     2  ...     2
# 4     480008     4    -1     1     1     2     4     1     1     1  ...     1
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 5831  477662     1     1     3     1     1     2     1     1     2  ...     2
# 5832  477663     1     1     3     2     2     1     1     1     2  ...     1
# 5833  488322     1     3     4     2     4     2     2     1     1  ...     2
# 5834  488325     4     3     3     3     3     3     2     2    -1  ...     2
# 5835  477666     1     1     4     3     2     3     1     1     1  ...     1
#
# ...

# %%
(RespId, Q3_1, Q3_2, Q3_3, Q3_4, Q3_5, Q3_6, Q4_1, Q4_2, Q4_3, Q4_4, Q4_5, Q4_6, Q5, Q30, ppage, educ, race, gender, income_cat y voter_category

# %% [markdown]
# ***Missing cleaning all columns and generating 'nonvoters_data_clean.csv' with Python.

# %%
non_voters_df = pd.read_csv('nonvoters_data_clean.csv')
non_voters_df
# Out:
#       RespId  Q3_1  Q3_2  Q3_3  Q3_4  Q3_5  Q3_6  Q4_1  Q4_2  Q4_3  ...  Q4_5  \
# 0     470001     1     1     4     4     3     2     2     1     2  ...     2
# 1     470002     3     3     4     3     3     2     2     2     2  ...     3
# 2     470003     2     2     3     3     2     2     2     2     3  ...     2
# 3     470007     1     1     4     4     2     1     1     2     2  ...     2
# 4     480008     4    -1     1     1     2     4     1     1     1  ...     1
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 5831  477662     1     1     3     1     1     2     1     1     2  ...     2
# 5832  477663     1     1     3     2     2     1     1     1     2  ...     1
# 5833  488322     1     3     4     2     4     2     2     1     1  ...     2
# 5834  488325     4     3     3     3     3     3     2     2    -1  ...     2
# 5835  477666     1     1     4     3     2     3     1     1     1  ...     1
#
# ...

# %%
clean_non_voters_df = non_voters_df.replace(-1,1)

# %%
clean_non_voters_df.describe()
# Out:
#               RespId         Q3_1         Q3_2         Q3_3         Q3_4  \
# count    5836.000000  5836.000000  5836.000000  5836.000000  5836.000000
# mean   474653.997772     1.917409     2.402673     2.648561     1.873372
# std      3628.475677     1.043706     1.156311     1.073814     0.965508
# min    470001.000000     1.000000     1.000000     1.000000     1.000000
# 25%    472069.750000     1.000000     1.000000     2.000000     1.000000
# 50%    474152.000000     2.000000     2.000000     3.000000     2.000000
# 75%    476217.500000     3.000000     3.000000     4.000000     2.000000
# max    488325.000000     4.000000     4.000000     4.000000     4.000000
#
#               Q3_5         Q3_6         Q4_1         Q4_2         Q4_3  ...  \
# count  5836.000000  5836.000000  5836.000000  5836.000000  5836.000000  ...
# mean      2.031186     2.078821     1.809287     1.842700     2.014222  ...
# std       0.831505     0.949788     0.891042     0.864575     0.901282  ...
# ...

# %%
clean_non_voters_df = clean_non_voters_df.set_index('RespId')
clean_non_voters_df
# Out:
#         Q3_1  Q3_2  Q3_3  Q3_4  Q3_5  Q3_6  Q4_1  Q4_2  Q4_3  Q4_4  Q4_5  \
# RespId
# 470001     1     1     4     4     3     2     2     1     2     2     2
# 470002     3     3     4     3     3     2     2     2     2     3     3
# 470003     2     2     3     3     2     2     2     2     3     3     2
# 470007     1     1     4     4     2     1     1     2     2     2     2
# 480008     4     1     1     1     2     4     1     1     1     1     1
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 477662     1     1     3     1     1     2     1     1     2     2     2
# 477663     1     1     3     2     2     1     1     1     2     3     1
# 488322     1     3     4     2     4     2     2     1     1     2     2
# 488325     4     3     3     3     3     3     2     2     1     2     2
# 477666     1     1     4     3     2     3     1     1     1     3     1
#
#         Q4_6  Q5  Q30  ppage  educ  race  gender  income_cat  voter_category
# ...

# %%
clean_non_voters_df.to_csv('nonvoters_data_clean.csv')
